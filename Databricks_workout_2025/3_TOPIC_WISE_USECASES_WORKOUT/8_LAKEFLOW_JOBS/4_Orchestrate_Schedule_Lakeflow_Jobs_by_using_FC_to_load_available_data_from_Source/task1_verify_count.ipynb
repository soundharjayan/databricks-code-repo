# %%
row_count = spark.sql("""select * from gcp_mysql_fc_we3.logistics.shipments1 where updated_at > (select coalesce(max(updated_at),'1970-01-01')from soundhar_catalog.soundhar_schema.shipment_his_ingestion)""").count()
print(row_count)

# %%
dbutils.jobs.taskValues.set(key='row_count',value =row_count)
